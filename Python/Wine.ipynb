# %%
#importing your csv file

# %%
import pandas as pd
import numpy
winedf = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13728/2113033337.py in <module>
#       1 import pandas as pd
#       2 import numpy
# ----> 3 winedf = pd.read_csv("http://www.cv.jinkan.kyoto-u.ac.jp/site/uploads/K-SCD.xlsm")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#exploring you columns
winedf.columns
# Out:
# Index(['1', '14.23', '1.71', '2.43', '15.6', '127', '2.8', '3.06', '.28',
#        '2.29', '5.64', '1.04', '3.92', '1065'],
#       dtype='object')

# %%
winedf.sample(10)
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  \
# 168  3  13.40  4.60  2.86  25.0  112  1.98  0.96  0.27  1.11  8.50  0.67
# 72   2  12.99  1.67  2.60  30.0  139  3.30  2.89  0.21  1.96  3.35  1.31
# 66   2  12.37  1.17  1.92  19.6   78  2.11  2.00  0.27  1.04  4.68  1.12
# 21   1  13.71  1.86  2.36  16.6  101  2.61  2.88  0.27  1.69  3.80  1.11
# 147  3  13.32  3.24  2.38  21.5   92  1.93  0.76  0.45  1.25  8.42  0.55
# 154  3  13.17  5.19  2.32  22.0   93  1.74  0.63  0.61  1.55  7.90  0.60
# 61   2  13.67  1.25  1.92  18.0   94  2.10  1.79  0.32  0.73  3.80  1.23
# 160  3  13.69  3.26  2.54  20.0  107  1.83  0.56  0.50  0.80  5.88  0.96
# 90   2  12.00  1.51  2.42  22.0   86  1.45  1.25  0.50  1.63  3.60  1.05
# 94   2  12.47  1.52  2.20  19.0  162  2.50  2.27  0.32  3.28  2.60  1.16
#
#      3.92  1065
# 168  1.92   630
# 72   3.50   985
# 66   3.48   510
# 21   4.00  1035
# 147  1.62   650
# 154  1.48   725
# 61   2.46   630
# 160  1.82   680
# ...
